# %%
# !pip install langchain langchain-google-genai google-generativeai python-dotenv

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

response = llm.invoke("Explain what LangChain does in simple terms")

print(response.content)
# Out:
# Imagine you have a super-smart brain (that's the Large Language Model or LLM, like ChatGPT). This brain is amazing at understanding and generating text.
#
# However, this brain has a few limitations:
# 1.  **It only knows what it was trained on.** It doesn't know about current events, your personal documents, or the latest stock prices.
# 2.  **It can't *do* anything.** It can't browse the internet, send an email, set a reminder, or perform calculations.
# 3.  **It forgets things.** Each time you ask it a question, it's like a fresh start; it doesn't remember your previous conversation unless you explicitly remind it.
# 4.  **It struggles with complex, multi-step tasks.**
#
# **LangChain is like a toolkit or a "super-powered assistant" that gives this smart brain (the LLM) all the extra capabilities it needs to be truly useful in the real world.**
#
# Here's what LangChain helps the LLM do:
#
# 1.  **Connect to the Outside World (Data):**
#     *   **Think of it like:** Giving the brain access to a vast library, the internet, your personal files (PDFs, Word docs), and databases.
#     *   **What it does:** LangChain allows the LLM to fetch information from *anywhere* – your company's internal documents, live web searches, specific databases, etc. This means the LLM can answer questions based on *current* or *private* information, not just its training data.
#
# 2.  **Use Tools (Actions):**
#     *   **Think of it like:** Giving the brain hands and access to various gadgets.
#     *   **What it does:** LangChain enables the LLM to use external tools. For example, it can use a calculator to do math, a search engine to find real-time information, an email client to send an email, or a calendar app to schedule an appointment.
#
# 3.  **Remember Conversations (Memory):**
#     *   **Think of it like:** Giving the brain a notepad to remember what you've talked about.
#     *   **What it does:** LangChain helps the LLM keep track of the conversation history, so it can understand context and respond more naturally over multiple turns, just like a human would.
#
# 4.  **Break Down Complex Tasks (Chains):**
#     *   **Think of it like:** Giving the brain a step-by-step instruction manual for big projects.
#     *   **What it does:** LangChain helps you define a sequence of actions for the LLM. For example, if you ask "Summarize this document and then email it to John," LangChain can orchestrate the steps: first, read and summarize the document using the LLM, then use an email tool to send the summary.
#
# **In simple terms:**
#
# LangChain takes a powerful but isolated "brain" (the LLM) and turns it into a **fully functional, interactive, and context-aware agent** that can access real-time information, perform actions, remember past interactions, and handle complex tasks. It's the glue that makes LLMs practical for building sophisticated AI applications like advanced chatbots, intelligent assistants, and automated workflows.

# %%
from langchain_core.prompts import PromptTemplate,ChatPromptTemplate
prompt = PromptTemplate(
    input_variables=["question"],
    template="Explain this to a beginner: {question}"
)
#print(prompt.format(question="what is rag in 1 line"))
response=llm.invoke(prompt.format(question="what is rag in 1 line?"))
#print(response.content)

prompt=ChatPromptTemplate([
    ("system","you are a chatbot with name {name} and answer user question"),
    ("human","question is {question}")
])

print(prompt.format(question="what is rag in 1 line?",name="bob"))
response=llm.invoke(prompt.format(question="what is rag in 1 line?",name="bob"))
print(response.content)
# Out:
# System: you are a chatbot with name bob and answer user question
# Human: question is what is rag in 1 line?
# Bob: RAG enhances large language models by retrieving external information to generate more accurate and contextually relevant responses.

# %%
from langchain_core.output_parsers import JsonOutputParser

parser = JsonOutputParser()


response=llm.invoke("Give me a person object in Json Format with fields: name, age")
print(response.content)
result =  parser.parse(response.content)

print(result)
# Out:
# ```json
# {
#   "name": "John Doe",
#   "age": 30
# }
# ```
# {'name': 'John Doe', 'age': 30}

# %%
from langchain_google_genai import GoogleGenerativeAI
from langchain_core.output_parsers import StrOutputParser

prompt = PromptTemplate.from_template("What is {component} in langchain?")
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
parse=StrOutputParser()
chain = prompt | llm | parse
response=chain.invoke({"component":"Models"})

print(response)
# Out:
# In Langchain, **Models** refer to the underlying **language models (LLMs)** or **chat models** that your application interacts with. These are the core components responsible for generating text, understanding prompts, and performing various natural language processing tasks.
#
# Langchain acts as a framework to abstract away the complexities of interacting with different LLMs, allowing you to easily switch between them and build sophisticated applications without being locked into a single provider.
#
# Here's a breakdown of what "Models" means in Langchain:
#
# **1. LLMs (Language Models):**
#
# *   **What they are:** These are models that take a **string** as input (your prompt) and return a **string** as output (the generated text). They are good for tasks like text generation, summarization, translation, and question answering where the output is primarily free-form text.
# *   **Examples:** OpenAI's GPT-3.5, GPT-4, Cohere's models, Hugging Face models.
# *   **Langchain Integration:** Langchain provides a unified interface to interact with various LLMs. You'll typically define an `LLM` object in Langchain, specifying which model you want to use and any associated parameters (like temperature, max tokens, etc.).
#
# **2. Chat Models:**
#
# *   **What they are:** These models are designed for **conversational AI**. They take a **list of messages** (representing a conversation history) as input and return a **message** as output. This allows them to maintain context and have more coherent multi-turn conversations.
# *   **Key Difference from LLMs:** The input and output format is structured around messages, which typically include roles (e.g., "system," "human," "AI"). This is crucial for building chatbots and other interactive applications.
# *   **Examples:** OpenAI's `gpt-3.5-turbo`, `gpt-4` (when used in chat mode), Anthropic's Claude models.
# *   **Langchain Integration:** Langchain has a dedicated `ChatModel` class, which is similar to `LLM` but handles message-based interactions.
#
# **Why is this abstraction important in Langchain?**
#
# *   **Flexibility:** You can easily swap out one LLM for another without rewriting significant portions of your code. This allows you to experiment with different models, compare their performance, and choose the best one for your specific needs and budget.
# *   **Standardization:** Langchain provides a consistent API for interacting with all supported models. This simplifies development and makes your code more readable and maintainable.
# *   **Integration with other Langchain components:** Models are the foundation upon which other Langchain components are built. Chains, agents, memory, document loaders, and retrievers all rely on interacting with models to perform their functions.
#
# **Key Concepts related to Models in Langchain:**
#
# *   **Model Providers:** Langchain supports a wide range of model providers, including OpenAI, Hugging Face, Cohere, Anthropic, and many more.
# *   **Model Configuration:** You'll often configure models with parameters like:
#     *   `temperature`: Controls the randomness of the output. Higher values lead to more creative but potentially less coherent text.
#     *   `max_tokens`: Limits the length of the generated output.
#     *   `model_name`: Specifies the particular model you want to use (e.g., "gpt-4", "text-davinci-003").
# *   **Prompting:** How you structure your input (prompts) is crucial for getting the desired output from the models. Langchain provides tools for efficient prompt management.
# *   **Output Parsers:** After a model generates output, you often need to extract structured information from it. Langchain's output parsers help with this.
#
# **In essence, when you're working with Langchain, "Models" are the intelligent engines that power your AI applications. Langchain's role is to provide a smooth and powerful way to connect to and utilize these engines.**

# %%
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain.tools import tool
@tool
def multiply(a:int,b:int)->int:
    """multiply two numbers"""
    return a*b

llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
agent=create_agent(model=llm,tools=[multiply])
response=agent.invoke({"messages": [HumanMessage("what is 2 times 3")]})

print(response)
# Out:
# hello world
# hello world
# hello world
# hello world
# {'messages': [HumanMessage(content='what is 2 times 3', additional_kwargs={}, response_metadata={}, id='7ad58592-36c9-44e4-ad28-0fb74b9a3eb3'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"a": 2, "b": 3}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc258-5639-76f3-9664-3936b4bb6a40-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'abddcef4-816b-4378-bcc0-a25dfec08a24', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 18, 'total_tokens': 70, 'input_token_details': {'cache_read': 0}}), ToolMessage(content='6', name='multiply', id='a81d7cfd-833e-4b5e-92a9-18e5980809d4', tool_call_id='abddcef4-816b-4378-bcc0-a25dfec08a24'), AIMessage(content='The answer is 6.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc258-5972-7a62-960e-b1b59a73564a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 83, 'output_tokens': 6, 'total_tokens': 89, 'input_token_details': {'cache_read': 0}})]}

# %%
# Out:
# {'messages': [HumanMessage(content='what is my name', additional_kwargs={}, response_metadata={}, id='5ac5cc80-e716-4510-b0ed-e1046977f47b'), AIMessage(content='I do not have access to your personal information, so I cannot tell you what your name is.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc258-848c-71f1-85a0-93870e64dd15-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 20, 'total_tokens': 69, 'input_token_details': {'cache_read': 0}})]}
# {'messages': [HumanMessage(content='my name is bob', additional_kwargs={}, response_metadata={}, id='d0b7f36c-1228-4e2a-9162-d24e12e02513'), AIMessage(content='Hi Bob, it is nice to meet you!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cc258-8837-7ee1-a75e-4389b9aec899-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 49, 'output_tokens': 10, 'total_tokens': 59, 'input_token_details': {'cache_read': 0}})]}
